# %%
import numpy as np
import pandas as pd
# RECORDS 
pd.read_json('y77d-th95.json', orient='records').head(2) # here you see that it plots out not well
# Out:
#      name  id nametype recclass   mass  fall                     year  \
# 0  Aachen   1    Valid       L5   21.0  Fell  1880-01-01T00:00:00.000
# 1  Aarhus   2    Valid       H6  720.0  Fell  1951-01-01T00:00:00.000
#
#      reclat   reclong                                        geolocation  \
# 0  50.77500   6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  56.18333  10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# 1                          NaN                          NaN

# %%
# INDEX
# pd.read_json('y77d-th95.json', orient='index').head(2) 
# AttributeError: 'list' object has no attribute 'values'

# %%
# COLUMNS
pd.read_json('y77d-th95.json', orient='columns').transpose()
# . transpose doesnt make the data better 
#pd.read_json('y77d-th95.json', orient='columns').head(2)
# here again you see that it plots the same 'records structure '
# Out:
#                                                                            0    \
# name                                                                    Aachen
# id                                                                           1
# nametype                                                                 Valid
# recclass                                                                    L5
# mass                                                                        21
# fall                                                                      Fell
# year                                                   1880-01-01T00:00:00.000
# reclat                                                                  50.775
# reclong                                                                6.08333
# geolocation                  {'type': 'Point', 'coordinates': [6.08333, 50....
# :@computed_region_cbhk_fwbd                                                NaN
# ...

# %%
# VALUES 
pd.read_json('y77d-th95.json', orient='values').head(2)
# here again you see that it plots the same 'records structure' and 'colums'
# Out:
#      name  id nametype recclass   mass  fall                     year  \
# 0  Aachen   1    Valid       L5   21.0  Fell  1880-01-01T00:00:00.000
# 1  Aarhus   2    Valid       H6  720.0  Fell  1951-01-01T00:00:00.000
#
#      reclat   reclong                                        geolocation  \
# 0  50.77500   6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  56.18333  10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# 1                          NaN                          NaN

# %%
# TABLE
# pd.read_json('y77d-th95.json', orient='table').head(2) 
# TypeError: list indices must be integers or slices, not str

# %%
# RECORDS 
pd.read_json('y77d-th95.json', orient='records').head(2)
# Out:
#      name  id nametype recclass   mass  fall                     year  \
# 0  Aachen   1    Valid       L5   21.0  Fell  1880-01-01T00:00:00.000
# 1  Aarhus   2    Valid       H6  720.0  Fell  1951-01-01T00:00:00.000
#
#      reclat   reclong                                        geolocation  \
# 0  50.77500   6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  56.18333  10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# 1                          NaN                          NaN

# %%
# SPLIT  
#pd.read_json('y77d-th95.json', orient='split').head(2)
#'list' object has no attribute 'items'
